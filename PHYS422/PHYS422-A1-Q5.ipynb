# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
y=0
x, z = meshgrid(arange(-0.8, 0.9, 0.1),arange(-0.8, 0.9, 0.1))

u = x/(x**2+y**2+(z-1)**2)**1.5+x/(x**2+y**2+(z+1)**2)**1.5-\
(x-1)/((x-1)**2+y**2+z**2)**1.5-(x+1)/((x+1)**2+y**2+z**2)**1.5


w = (z-1)/(x**2+y**2+(z-1)**2)**1.5+(z+1)/(x**2+y**2+(z+1)**2)**1.5-\
z/((x-1)**2+y**2+z**2)**1.5-z/((x+1)**2+y**2+z**2)**1.5

P_0 = 1/(x**2+y**2+(z-1)**2)**0.5+1/(x**2+y**2+(z+1)**2)**0.5-\
1/((x-1)**2+y**2+z**2)**0.5-1/((x+1)**2+y**2+z**2)**0.5

figure()
M = hypot(u, w)
Q = quiver(x, z, u, w,M,width=0.004,scale=100)
scatter(x, z, color='k',s=1)
im = imshow(P_0, extent=(amin(x),amax(x),amin(z),amax(z)),cmap=plt.get_cmap('jet'),vmin=-5,vmax=5)
cb=colorbar(im)
cb.set_label(r'Potential (scaled by 4$\pi \epsilon_0 a/q_0$) ')
title(r'the electric field in $x-z$ plane')
xlabel(r'$x/a$')
ylabel(r'$z/a$')
show()

# %%
y=0
x, z = meshgrid(arange(-0.8, 0.9, 0.1),arange(-0.8, 0.9, 0.1))

u = x/(x**2+y**2+(z-1)**2)**1.5+x/(x**2+y**2+(z+1)**2)**1.5-\
(x-1)/((x-1)**2+y**2+z**2)**1.5-(x+1)/((x+1)**2+y**2+z**2)**1.5


w = (z-1)/(x**2+y**2+(z-1)**2)**1.5+(z+1)/(x**2+y**2+(z+1)**2)**1.5-\
z/((x-1)**2+y**2+z**2)**1.5-z/((x+1)**2+y**2+z**2)**1.5

P_0 =(u**2+w**2)**0.5

figure()
M = hypot(u, w)
Q = quiver(x, z, u, w,M,width=0.004,scale=100)
scatter(x, z, color='r',s=1)
im = imshow(P_0, extent=(amin(x),amax(x),amin(z),amax(z)),cmap=plt.get_cmap('Greys'),vmin=0,vmax=10)
cb=colorbar(im)
cb.set_label(r'magnitue of E (scaled by 4$\pi \epsilon_0 a^2/q_0$) ')
title(r'the electric field in $x-z$ plane')
xlabel(r'$x/a$')
ylabel(r'$z/a$')
show()

# %%
z=0


x, y = meshgrid(arange(-0.8, 0.81, 0.1),arange(-0.8, 0.81, 0.1))


P_0 = 1/(x**2+y**2+(z-1)**2)**0.5+1/(x**2+y**2+(z+1)**2)**0.5-\
1/((x-1)**2+y**2+z**2)**0.5-1/((x+1)**2+y**2+z**2)**0.5

u = x/(x**2+y**2+(z-1)**2)**1.5+x/(x**2+y**2+(z+1)**2)**1.5-\
(x-1)/((x-1)**2+y**2+z**2)**1.5-(x+1)/((x+1)**2+y**2+z**2)**1.5

v = y/(x**2+y**2+(z-1)**2)**1.5+y/(x**2+y**2+(z+1)**2)**1.5-\
y/((x-1)**2+y**2+z**2)**1.5-y/((x+1)**2+y**2+z**2)**1.5

figure()
M = hypot(u, v)
Q = quiver(x, y, u, v,M,width=0.008,scale=100)
scatter(x, y, color='k',s=1)
im = imshow(P_0, extent=(amin(x),amax(x),amin(y),amax(y)),cmap=plt.get_cmap('plasma'),vmin=-3.5,vmax=0)
cb=colorbar(im)
cb.set_label(r'Potential (scaled by 4$\pi \epsilon_0 a/q_0$) ')
title(r'the electric field in $x-y$ plane')
xlabel(r'$x/a$')
ylabel(r'$y/a$')
show()

# %%
z=0


x, y = meshgrid(arange(-0.8, 0.81, 0.1),arange(-0.8, 0.81, 0.1))

u = x/(x**2+y**2+(z-1)**2)**1.5+x/(x**2+y**2+(z+1)**2)**1.5-\
(x-1)/((x-1)**2+y**2+z**2)**1.5-(x+1)/((x+1)**2+y**2+z**2)**1.5

v = y/(x**2+y**2+(z-1)**2)**1.5+y/(x**2+y**2+(z+1)**2)**1.5-\
y/((x-1)**2+y**2+z**2)**1.5-y/((x+1)**2+y**2+z**2)**1.5

P_0 =(u**2+v**2)**0.5


figure()
M = hypot(u, v)
Q = quiver(x, y, u, v,M,width=0.008,scale=100)
scatter(x, y, color='k',s=1)
im = imshow(P_0, extent=(amin(x),amax(x),amin(y),amax(y)),cmap=plt.get_cmap('Wistia'),vmin=0,vmax=10)
cb=colorbar(im)
cb.set_label(r'magnitue of E (scaled by 4$\pi \epsilon_0 a^2/q_0$) ')
title(r'the electric field in $x-y$ plane')
xlabel(r'$x/a$')
ylabel(r'$y/a$')
show()

# %%
import matplotlib.gridspec as gridspec

# %%
y=0
m=1.5
d=0.001
x, z = meshgrid(arange(-m, m+d, d),arange(-m, m+d, d))

u = x/(x**2+y**2+(z-1)**2)**1.5+x/(x**2+y**2+(z+1)**2)**1.5-\
(x-1)/((x-1)**2+y**2+z**2)**1.5-(x+1)/((x+1)**2+y**2+z**2)**1.5


w = (z-1)/(x**2+y**2+(z-1)**2)**1.5+(z+1)/(x**2+y**2+(z+1)**2)**1.5-\
z/((x-1)**2+y**2+z**2)**1.5-z/((x+1)**2+y**2+z**2)**1.5

speed = sqrt(u**2 + w**2)

fig = plt.figure(figsize=(20, 30))
gs = gridspec.GridSpec(nrows=3, ncols=2, height_ratios=[1, 1, 2])
ax0 = fig.add_subplot(gs[0, 0])
ax0.streamplot(x, z, u, w, density=[1, 2], color='k')
P_0 = 1/(x**2+y**2+(z-1)**2)**0.5+1/(x**2+y**2+(z+1)**2)**0.5-\
1/((x-1)**2+y**2+z**2)**0.5-1/((x+1)**2+y**2+z**2)**0.5

im = imshow(P_0, extent=(amin(x),amax(x),amin(z),amax(z)),cmap=plt.get_cmap('jet'),vmin=-5,vmax=5)
cb=colorbar(im)
cb.set_label(r'Potential (scaled by 4$\pi \epsilon_0 a/q_0$) ')

title(r'the electric field in $x-z$ plane')
xlabel(r'$x/a$')
ylabel(r'$z/a$')
show()

# %%
y=0
m=1.5
d=0.001
x, z = meshgrid(arange(-m, m+d, d),arange(-m, m+d, d))

u = x/(x**2+y**2+(z-1)**2)**1.5+x/(x**2+y**2+(z+1)**2)**1.5-\
(x-1)/((x-1)**2+y**2+z**2)**1.5-(x+1)/((x+1)**2+y**2+z**2)**1.5


w = (z-1)/(x**2+y**2+(z-1)**2)**1.5+(z+1)/(x**2+y**2+(z+1)**2)**1.5-\
z/((x-1)**2+y**2+z**2)**1.5-z/((x+1)**2+y**2+z**2)**1.5

speed = sqrt(u**2 + w**2)

fig = plt.figure(figsize=(20, 30))
gs = gridspec.GridSpec(nrows=3, ncols=2, height_ratios=[1, 1, 2])
ax0 = fig.add_subplot(gs[0, 0])
ax0.streamplot(x, z, u, w, density=[1, 2], color='k')
P_0 =((u**2+w**2)**0.5)

im = imshow(P_0, extent=(amin(x),amax(x),amin(z),amax(z)),cmap=plt.get_cmap('jet'),vmin=0,vmax=5)
cb=colorbar(im)
cb.set_label(r'4$\pi \epsilon_0 a^2/q_0 $ E  ')

title(r'the electric field in $x-z$ plane')
xlabel(r'$x/a$')
ylabel(r'$z/a$')
show()
