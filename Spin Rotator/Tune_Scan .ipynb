# %%
# %pylab inline
import pandas as pd
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# %matplotlib notebook

# %%
df = pd.read_fwf('her_tune_scan.txt')

# %%
df
# Out:
#     ja  jb  jz   Q_a   Q_b   Q_z  data_turns  Amp_a_rms  Amp_b_rms  Amp_z_rms  \
# 0    0   0   0  0.40  0.40  0.05         100   0.152760   1.610300    0.19578
# 1    1   0   0  0.41  0.40  0.05         100   0.154410   0.103940    0.19839
# 2    2   0   0  0.42  0.40  0.05         100   0.116980   0.100410    0.18129
# 3    3   0   0  0.43  0.40  0.05         100   0.131580   0.107600    0.18730
# 4    4   0   0  0.44  0.40  0.05         100   0.136300   0.144050    0.33525
# 5    5   0   0  0.45  0.40  0.05         100   0.137860   0.114540    0.28837
# 6    0   1   0  0.40  0.41  0.05         100   0.126450   0.102280    0.21324
# 7    1   1   0  0.41  0.41  0.05         100   0.125770   1.851200    0.26673
# 8    2   1   0  0.42  0.41  0.05         100   0.159310   0.104600    0.26384
# 9    3   1   0  0.43  0.41  0.05         100   0.120350   0.103580    0.23336
# 10   4   1   0  0.44  0.41  0.05         100   0.125860   0.098526    0.20554
# ...

# %%
arr = df.to_numpy()

# %%
qa = arr[:24,3]; qb = arr[:24,4]; Amp_a_max = arr[:24,10]; Amp_b_max = arr[:24,11]
Amp_a_max = Amp_a_max.reshape(4,6)
Amp_b_max = Amp_b_max.reshape(4,6)

# %%
figure(figsize=(10, 8))
im = imshow(Amp_a_max, extent=(amin(qa),amax(qa),amin(qb),amax(qb)), cmap=plt.get_cmap('jet'), vmin = 1, vmax = 1.5)
colorbar(im)
xlabel('Qa')
ylabel('Qb')
title('Amp_a_max')
show()
# Out:
# <img src="data:image/png;base64,..." width="720">

# %%
figure(figsize=(10, 8))
im = imshow(Amp_b_max, extent=(amin(qa),amax(qa),amin(qb),amax(qb)),cmap=plt.get_cmap('jet'), vmin = 1, vmax = 1.5)
colorbar(im)
xlabel('Qa')
ylabel('Qb')
title('Amp_b_max')
show()
# Out:
# <img src="data:image/png;base64,..." width="720">
